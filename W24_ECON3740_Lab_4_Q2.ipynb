# %% [markdown]
# <a href="https://colab.research.google.com/github/havaledar/ECON3740/blob/main/W24_ECON3740_Lab_4_Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Libraries

# %%
# Installing Libraries
# !pip install stargazer
# !pip install gdown==v4.6.3

# Importing Libraries
import pandas as pd
import numpy as np
from stargazer.stargazer import Stargazer
import gdown
import statsmodels.formula.api as smf
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.7.3
#     Uninstalling gdown-4.7.3:
#       Successfully uninstalled gdown-4.7.3
# ...

# %% [markdown]
# #A2

# %%
url = 'https://drive.google.com/file/d/1FAfkh6Pr6J3CRCLs8ql8QMCa1309fcEU/view?usp=drive_link'
output_filename = 'ceosal.dta'
gdown.download(url, output_filename, fuzzy=True ,quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1FAfkh6Pr6J3CRCLs8ql8QMCa1309fcEU
# To: /content/ceosal.dta
# 100%|██████████| 13.9k/13.9k [00:00<00:00, 9.96MB/s]
# 'ceosal.dta'

# %%
ceosal = pd.read_stata('/content/ceosal (1).dta')

# %%
CEOSAL = ceosal

# %%
CEOSAL[CEOSAL['age'] <= 72].shape
# Out:
# (171, 13)

# %%
CEOSAL = CEOSAL[CEOSAL['age'] <= 72]

# %%
CEOSAL.shape
# Out:
# (171, 13)

# %%
CEOSAL.describe()
# Out:
#             salary        age  college       grad     comten     ceoten  \
# count    34.000000  34.000000     34.0  34.000000  34.000000  34.000000
# mean    762.705882  43.941176      1.0   0.676471  11.705882   6.264706
# std     522.927745   3.773441      0.0   0.474858   6.117681   5.451210
# min     245.000000  33.000000      1.0   0.000000   2.000000   0.000000
# 25%     399.500000  41.250000      1.0   0.000000   7.000000   2.250000
# 50%     603.500000  44.500000      1.0   1.000000  10.500000   4.500000
# 75%     960.000000  46.750000      1.0   1.000000  17.750000   8.750000
# max    2792.000000  49.000000      1.0   1.000000  24.000000  24.000000
#
#              sales     profits        mktval    comtensq    ceotensq  \
# count    34.000000   34.000000     34.000000   34.000000   34.000000
# mean   1099.264648   82.647059   1993.911743  173.352941   68.088235
# std    1414.540039  176.127172   3996.898438  157.706264  119.569776
# ...

# %%
CEOSAL['age'].describe()
# Out:
# count    34.000000
# mean     43.941176
# std       3.773441
# min      33.000000
# 25%      41.250000
# 50%      44.500000
# 75%      46.750000
# max      49.000000
# Name: age, dtype: float64

# %%
CEOSAL['ceoten'].describe()
# Out:
# count    34.000000
# mean      6.264706
# std       5.451210
# min       0.000000
# 25%       2.250000
# 50%       4.500000
# 75%       8.750000
# max      24.000000
# Name: ceoten, dtype: float64

# %%
CEOSAL['salary'].describe()
# Out:
# count      34.000000
# mean      762.705882
# std       522.927745
# min       245.000000
# 25%       399.500000
# 50%       603.500000
# 75%       960.000000
# max      2792.000000
# Name: salary, dtype: float64

# %%
CEOSAL['ceoten'].value_counts().sort_index()
# Out:
# 0     1
# 1     4
# 2     4
# 3     4
# 4     4
# 5     2
# 6     2
# 7     3
# 8     1
# 9     1
# 10    2
# 11    1
# 12    2
# 14    1
# 20    1
# 24    1
# Name: ceoten, dtype: int64

# %%
m1 = smf.ols('salary ~ ceoten', CEOSAL)

results = m1.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.6653
# Date:                Fri, 26 Jan 2024   Prob (F-statistic):              0.421
# Time:                        14:33:25   Log-Likelihood:                -260.21
# No. Observations:                  34   AIC:                             524.4
# Df Residuals:                      32   BIC:                             527.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    676.9421    138.497      4.888      0.000     394.832     959.052
# ...

# %%
CEOSAL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 0 to 167
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   salary    34 non-null     Int16
#  1   age       34 non-null     Int8
#  2   college   34 non-null     Int8
#  3   grad      34 non-null     Int8
#  4   comten    34 non-null     Int8
#  5   ceoten    34 non-null     Int8
#  6   sales     34 non-null     Int64
#  7   profits   34 non-null     Int16
#  8   mktval    34 non-null     Int64
#  9   comtensq  34 non-null     Int16
#  10  ceotensq  34 non-null     Int16
#  11  profmarg  34 non-null     Float32
#  12  nsal      34 non-null     Int64
#  13  newsal    34 non-null     Int16
# dtypes: Float32(1), Int16(5), Int64(3), Int8(5)
# memory usage: 2.2 KB

# %%
# Convert the 'salary' column to a larger integer type
CEOSAL['salary'] = CEOSAL['salary'].astype('int64')

# Multiply the 'salary' column by 1000
CEOSAL['newsal'] = CEOSAL['salary'] * 1000

# %%
CEOSAL
# Out:
#      salary  age  college  grad  comten  ceoten  sales  profits  mktval  \
# 0      1161   49        1     1       9       2   6200      966   23200
# 1       600   43        1     1      10      10    283       48    1100
# 4       497   44        1     1       8       6    351       28     387
# 8       503   47        1     1       4       4    610        7     454
# 15      245   44        1     1       7       7    135       24     558
# 27      270   43        1     0      15       2    150       28     713
# 34      474   40        1     0      18       1   2700      117    2000
# 44     1550   47        1     1      19       3   1100      120    4900
# 52      649   44        1     1       4       4    336       17     475
# 64      526   45        1     0       8       7   2400      106    2000
# 73     2792   40        1     0      11      11    534       35     888
# 77      377   45        1     0       7       5    238       57    1200
# ...

# %%
CEOSAL = CEOSAL.convert_dtypes()

# %%
CEOSAL['salary'].astype(np.integer)*1000
# Out:
# 0      1161000
# 1       600000
# 4       497000
# 8       503000
# 15      245000
# 27      270000
# 34      474000
# 44     1550000
# 52      649000
# 64      526000
# 73     2792000
# 77      377000
# 79      720000
# 87     1248000
# 89      348000
# 94      323000
# 97      375000
# 101     491000
# 106     989000
# 110     849000
# 115     308000
# 116    1392000
# 121     707000
# 127    1630000
# 138     310000
# 143    1091000
# 146     607000
# 153     537000
# 154     693000
# 158     873000
# 162    1268000
# 164     693000
# 165     369000
# 167     467000
# Name: salary, dtype: int64

# %%
m2 = smf.ols('newsal ~ ceoten', CEOSAL)

results = m2.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 newsal   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.030
# Method:                 Least Squares   F-statistic:                   0.04428
# Date:                Fri, 26 Jan 2024   Prob (F-statistic):              0.835
# Time:                        14:41:57   Log-Likelihood:                -380.23
# No. Observations:                  34   AIC:                             764.5
# Df Residuals:                      32   BIC:                             767.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3695.8616   4725.787     -0.782      0.440   -1.33e+04    5930.252
# ...

# %%
m3 = smf.ols('mktval ~ ceoten', CEOSAL)

results = m3.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 mktval   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.5050
# Date:                Fri, 26 Jan 2024   Prob (F-statistic):              0.482
# Time:                        14:43:16   Log-Likelihood:                -329.44
# No. Observations:                  34   AIC:                             662.9
# Df Residuals:                      32   BIC:                             665.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2566.4532   1061.185      2.418      0.021     404.890    4728.016
# ...
